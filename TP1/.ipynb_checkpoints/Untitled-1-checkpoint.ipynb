# %% [markdown]
# ## TEST

# %%
from qiskit import QuantumCircuit
# Create quantum circuit with 3 qubits and 3 classical bits
# (we'll explain why we need the classical bits later)
qc = QuantumCircuit(3, 3)
qc.draw() # returns a drawing of the circuit
# Out:
#
# q_0:
#
# q_1:
#
# q_2:
#
# c: 3/

# %% [markdown]
# #### Portes importantes
#
# #### 1 qbit
#
# ##### Portes not (x-pauli)
#
# ##### Portes H
#
# #### 2 qbit
#
# ##### Porte 'c-not'
#
# Inverse les 11 et les 10
# En en enchainant 3 en alternance on peut créer une porte swap.
#
# ##### Porte swap
# Inverse l'état des deux qbits (l'algo est d'inverser 10 et 01)
#
# #### 3 qbit
#
# ##### Porte C SWAP

# %%
![title](schematic.png)
# Out:
# zsh:1: number expected
